# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix = pd.read_csv('/content/anetflix_titles.csv')
netflix
# Out:
#       Id     type                  title           director  \
# 0      1    Movie   Dick Johnson Is Dead    Kirsten Johnson
# 1      2  TV Show          Blood & Water                NaN
# 2      3  TV Show              Ganglands    Julien Leclercq
# 3      4  TV Show  Jailbirds New Orleans                NaN
# 4      5  TV Show           Kota Factory                NaN
# ..   ...      ...                    ...                ...
# 495  496    Movie              Awon Boyz  Tolulope Itegboje
# 496  497    Movie         Brick Mansions  Camille Delamarre
# 497  498  TV Show             Cat People                NaN
# 498  499    Movie                  Clash       Pascal Atuma
# 499  500  TV Show                   Dogs                NaN
#
#                                                   cast  \
# 0                                                  NaN
# 1    Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2    Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
netflix.head(5)
# Out:
#    Id     type                  title         director  \
# 0   1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1   2  TV Show          Blood & Water              NaN
# 2   3  TV Show              Ganglands  Julien Leclercq
# 3   4  TV Show  Jailbirds New Orleans              NaN
# 4   5  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 0                                                NaN           USA
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        France
# 3                                                NaN           USA
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
netflix.tail(10)
# Out:
#       Id     type                               title             director  \
# 490  491  TV Show  Elize Matsunaga: Once Upon a Crime                  NaN
# 491  492    Movie                          Home Again  Hallie Meyers-Shyer
# 492  493    Movie                        Midnight Sun          Scott Speer
# 493  494  TV Show    RESIDENT EVIL: Infinite Darkness                  NaN
# 494  495    Movie                     Rock the Kasbah       Barry Levinson
# 495  496    Movie                           Awon Boyz    Tolulope Itegboje
# 496  497    Movie                      Brick Mansions    Camille Delamarre
# 497  498  TV Show                          Cat People                  NaN
# 498  499    Movie                               Clash         Pascal Atuma
# 499  500  TV Show                                Dogs                  NaN
#
#                                                   cast  \
# 490                                                NaN
# ...

# %%
netflix.shape
# Out:
# (500, 12)

# %%
netflix.size
# Out:
# 6000

# %%
netflix.describe()
# Out:
#                Id  release_year
# count  500.000000    500.000000
# mean   250.500000   2014.436000
# std    144.481833      9.589673
# min      1.000000   1961.000000
# 25%    125.750000   2011.000000
# 50%    250.500000   2020.000000
# 75%    375.250000   2021.000000
# max    500.000000   2021.000000

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            500 non-null    int64
#  1   type          500 non-null    object
#  2   title         500 non-null    object
#  3   director      348 non-null    object
#  4   cast          442 non-null    object
#  5   country       500 non-null    object
#  6   date_added    500 non-null    object
#  7   release_year  500 non-null    int64
#  8   rating        500 non-null    object
#  9   duration      498 non-null    object
#  10  listed_in     500 non-null    object
#  11  description   500 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 47.0+ KB

# %%
columnlist=netflix.columns
columnlist
# Out:
# Index(['Id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.isnull()
# Out:
#         Id   type  title  director   cast  country  date_added  release_year  \
# 0    False  False  False     False   True    False       False         False
# 1    False  False  False      True  False    False       False         False
# 2    False  False  False     False  False    False       False         False
# 3    False  False  False      True   True    False       False         False
# 4    False  False  False      True  False    False       False         False
# ..     ...    ...    ...       ...    ...      ...         ...           ...
# 495  False  False  False     False   True    False       False         False
# 496  False  False  False     False  False    False       False         False
# 497  False  False  False      True   True    False       False         False
# 498  False  False  False     False  False    False       False         False
# 499  False  False  False      True   True    False       False         False
#
# ...

# %%
netflix.isnull().sum()
# Out:
# Id                0
# type              0
# title             0
# director        152
# cast             58
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          2
# listed_in         0
# description       0
# dtype: int64

# %%
duration=netflix['duration']
duration
# Out:
# 0         90 min
# 1      2 Seasons
# 2       1 Season
# 3       1 Season
# 4      2 Seasons
#          ...
# 495       38 min
# 496       90 min
# 497     1 Season
# 498       87 min
# 499    2 Seasons
# Name: duration, Length: 500, dtype: object

# %%
duration.fillna('90 min',inplace=True)
duration
# Out:
# 0         90 min
# 1      2 Seasons
# 2       1 Season
# 3       1 Season
# 4      2 Seasons
#          ...
# 495       38 min
# 496       90 min
# 497     1 Season
# 498       87 min
# 499    2 Seasons
# Name: duration, Length: 500, dtype: object

# %%
netflix.isnull().sum()
# Out:
# Id                0
# type              0
# title             0
# director        152
# cast             58
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
slicedlist=netflix.iloc[10:21]
slicedlist
# Out:
#     Id     type                                              title  \
# 10  11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11  12  TV Show                                   Bangkok Breaking
# 12  13    Movie                                       Je Suis Karl
# 13  14    Movie                   Confessions of an Invisible Girl
# 14  15  TV Show                    Crime Stories: India Detectives
# 15  16  TV Show                                  Dear White People
# 16  17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17  18  TV Show                                    Falsa identidad
# 18  19    Movie                                          Intrusion
# 19  20  TV Show                                             Jaguar
# 20  21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
#
#                                          director  \
# 10                                            NaN
# 11                              Kongkiat Komesiri
# ...

# %%
[netflix['country']=='India']
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  495    False
#  496    False
#  497    False
#  498    False
#  499    False
#  Name: country, Length: 500, dtype: bool]

# %%
x=netflix['type']
y=netflix['release_year']
plt.plot(x,y)

# %%
plt.title('Line Chart')
x=netflix['type']
y=netflix['release_year']
plt.plot(x,y)
plt.xlabel('type')
plt.ylabel('release year')
plt.show()

# %%
x=netflix['type']
y=netflix['release_year']
plt.bar(x,y)
plt.show()

# %%
x=netflix['country']
y=netflix['release_year']
plt.scatter(x,y)
plt.show()

# %%
data = netflix['type']
plt.hist(data)
plt.show()

# %%
plt.pie(netflix['release_year'], labels=netflix['title'])

plt.title('Pie Chart')

plt.show()
