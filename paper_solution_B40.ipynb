# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("cars.csv")
df
# Out:
#      Unnamed: 0    price      brand    model  year   title_status  mileage  \
# 0             0   6300.0     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899.0       ford       se  2011  clean vehicle   190552
# 2             2      NaN      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000.0       ford     door  2014  clean vehicle    64146
# 4             4  27700.0  chevrolet     1500  2018  clean vehicle     6654
# ..          ...      ...        ...      ...   ...            ...      ...
# 172         172   5470.0      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600.0       ford     door  2014  clean vehicle    75785
# 174         174  24502.0  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110.0       ford     door  2017  clean vehicle    42289
# 176         176   7900.0       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0    price      brand model  year   title_status  mileage  \
# 172         172   5470.0      dodge   mpv  2018  clean vehicle    39721
# 173         173  14600.0       ford  door  2014  clean vehicle    75785
# 174         174  24502.0  chevrolet  1500  2016  clean vehicle    33624
# 175         175  15110.0       ford  door  2017  clean vehicle    42289
# 176         176   7900.0       ford  door  2014  clean vehicle    79422
#
#      color                  vin        lot         state country  \
# 172  black    3c4pdcgg9jt216280  167656495       florida     usa
# 173  black    1fm5k8f81egb23411  167756284  pennsylvania     usa
# 174  black    3gcuknec6gg150809  167765812      michigan     usa
# 175  white    1ft7w2bt7hec67263  167656516         texas     usa
# 176  white    1fmcu0g9xeud52262  167756290      new york     usa
#
#          condition
# 172  16 hours left
# 173  21 hours left
# 174  20 hours left
# 175    2 days left
# 176  21 hours left

# %%
df.size
# Out:
# 2301

# %%
df.shape
# Out:
# (177, 13)

# %%
df.describe()
# Out:
#        Unnamed: 0         price         year        mileage           lot
# count  177.000000    177.000000   177.000000     177.000000  1.770000e+02
# mean    88.000000  17121.751412  2016.310734   46854.932203  1.676768e+08
# std     51.239633  11060.554802     4.084275   37352.978107  6.342515e+05
# min      0.000000      0.000000  1973.000000    2430.000000  1.593488e+08
# 25%     44.000000   7300.000000  2016.000000   28972.000000  1.676565e+08
# 50%     88.000000  15110.000000  2017.000000   35714.000000  1.677554e+08
# 75%    132.000000  23505.000000  2018.000000   48086.000000  1.677637e+08
# max    176.000000  55000.000000  2020.000000  274117.000000  1.678025e+08

# %%
brand=df['brand']
brand
# Out:
# 0         toyota
# 1           ford
# 2          dodge
# 3           ford
# 4      chevrolet
#          ...
# 172        dodge
# 173         ford
# 174    chevrolet
# 175         ford
# 176         ford
# Name: brand, Length: 177, dtype: object

# %%
df.isnull()
# Out:
#      Unnamed: 0  price  brand  model   year  title_status  mileage  color  \
# 0         False  False  False  False  False         False    False  False
# 1         False  False  False  False  False         False    False  False
# 2         False   True  False  False  False         False    False  False
# 3         False  False  False  False  False         False    False  False
# 4         False  False  False  False  False         False    False  False
# ..          ...    ...    ...    ...    ...           ...      ...    ...
# 172       False  False  False  False  False         False    False  False
# 173       False  False  False  False  False         False    False  False
# 174       False  False  False  False  False         False    False  False
# 175       False  False  False  False  False         False    False  False
# 176       False  False  False  False  False         False    False  False
#
#        vin    lot  state  country  condition
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# price           4
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           3
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
price=df['price']
price
# Out:
# 0       6300.0
# 1       2899.0
# 2          NaN
# 3      25000.0
# 4      27700.0
#         ...
# 172     5470.0
# 173    14600.0
# 174    24502.0
# 175    15110.0
# 176     7900.0
# Name: price, Length: 177, dtype: float64

# %%
pmean=price.mean()
pmean
# Out:
# 17295.49132947977

# %%
price.fillna(pmean,inplace=True)
price
# Out:
# 0       6300.000000
# 1       2899.000000
# 2      17295.491329
# 3      25000.000000
# 4      27700.000000
#            ...
# 172     5470.000000
# 173    14600.000000
# 174    24502.000000
# 175    15110.000000
# 176     7900.000000
# Name: price, Length: 177, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           3
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
df2=pd.read_csv("iris.csv")
df2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          NaN           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df2.head(4)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          NaN           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   146 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       146 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
species_count=df2['variety'].value_counts()
species_count
# Out:
# Versicolor    50
# Virginica     50
# Setosa        46
# Name: variety, dtype: int64

# %%
df2.size
# Out:
# 750

# %%
df2.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df22=df.iloc[80:101]
df22
# Out:
#      Unnamed: 0    price      brand       model  year   title_status  mileage  \
# 80           80  12520.0        gmc        door  2017  clean vehicle    31992
# 81           81  17900.0       jeep     compass  2019  clean vehicle    32501
# 82           82  18300.0  chevrolet      camaro  2017  clean vehicle    28395
# 83           83   4640.0       ford        door  2017  clean vehicle    36139
# 84           84  24000.0       ford        door  2016  clean vehicle    84413
# 85           85  13200.0        gmc        door  2017  clean vehicle    33457
# 86           86  18000.0       jeep     compass  2019  clean vehicle    29245
# 87           87  14900.0  chevrolet     equinox  2017  clean vehicle    12783
# 88           88   4140.0       ford        door  2017  clean vehicle    17617
# 89           89  11500.0       ford        door  2016  clean vehicle    36855
# 90           90   9110.0       ford        door  2017  clean vehicle   110316
# ...

# %%
df23=df2.drop_duplicates()
df23
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          NaN           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     4
# petal.length    0
# petal.width     0
# variety         4
# dtype: int64

# %%
variety=df2['variety']
variety
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
width=df2['petal.width']
width
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal.width, Length: 150, dtype: float64

# %%
widthm=width.median()
widthm
# Out:
# 1.3

# %%
width.fillna(widthm,inplace=True)
width
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal.width, Length: 150, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df2['sepal.length'],df2['sepal.width'])

# %%
df3=pd.read_csv('diamonds.csv')
df3
# Out:
#      carat      cut color clarity  depth  table   price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0  2777.0  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0  2777.0  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0  2777.0  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0  2777.0  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0  2777.0  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
df3.tail(5)
# Out:
#      carat      cut color clarity  depth  table   price     x     y     z
# 194    0.7  Premium     E     SI1   61.2   57.0  2777.0  5.73  5.68  3.49
# 195    0.7  Premium     E     SI1   62.7   59.0  2777.0  5.67  5.63  3.54
# 196    0.7  Premium     E     SI1   61.0   57.0  2777.0  5.73  5.68  3.48
# 197    0.7  Premium     E     SI1   61.0   58.0  2777.0  5.78  5.72  3.51
# 198    0.7    Ideal     E     SI1   61.4   57.0  2777.0  5.76  5.70  3.52

# %%
df3.describe()
# Out:
#             carat       depth       table        price           x  \
# count  199.000000  199.000000  199.000000   195.000000  199.000000
# mean     0.524020   61.629146   57.719598  1740.117949    5.047588
# std      0.237057    1.613471    2.355365  1161.146297    0.834121
# min      0.200000   55.100000   53.000000   326.000000    3.790000
# 25%      0.290000   60.800000   56.000000   404.000000    4.225000
# 50%      0.700000   61.700000   57.000000  2760.000000    5.560000
# 75%      0.720000   62.600000   59.000000  2768.000000    5.790000
# max      1.170000   66.300000   69.000000  2777.000000    6.830000
#
#                 y           z
# count  199.000000  199.000000
# mean     5.055075    3.112462
# std      0.823563    0.512692
# min      3.750000    2.270000
# 25%      4.250000    2.615000
# 50%      5.580000    3.380000
# 75%      5.780000    3.560000
# max      6.900000    4.130000

# %%
df3.drop_duplicates()
# Out:
#      carat      cut color clarity  depth  table   price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0  2777.0  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0  2777.0  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0  2777.0  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0  2777.0  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0  2777.0  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
df3[(df3['x']==0) | (df3['y']==0) | (df3['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
df3['total']=df3['x']*df3['y']*df3['z']
df3
# Out:
#      carat      cut color clarity  depth  table   price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0  2777.0  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0  2777.0  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0  2777.0  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0  2777.0  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0  2777.0  5.76  5.70  3.52
#
#           total
# 0     38.202030
# 1     34.505856
# 2     38.076885
# ...

# %%
df3.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      4
# x          0
# y          0
# z          0
# dtype: int64

# %%
price=df3['price']
price
# Out:
# 0       326.0
# 1       326.0
# 2       327.0
# 3       334.0
# 4       335.0
#         ...
# 194    2777.0
# 195    2777.0
# 196    2777.0
# 197    2777.0
# 198    2777.0
# Name: price, Length: 199, dtype: float64

# %%
mean=price.mean()
mean
# Out:
# 1740.1179487179488

# %%
price.fillna(mean,inplace=True)
price
# Out:
# 0       326.0
# 1       326.0
# 2       327.0
# 3       334.0
# 4       335.0
#         ...
# 194    2777.0
# 195    2777.0
# 196    2777.0
# 197    2777.0
# 198    2777.0
# Name: price, Length: 199, dtype: float64

# %%
df3.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df4=pd.read_csv('flight.csv')
df4
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
df4.tail(5)
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 194            1917      -12.0      B6    1016  N304JB    JFK  BOS      36.0
# 195            2110       -5.0      B6     989  N663JB    JFK  FLL     152.0
# 196            1943       37.0      UA    1676  N37274    EWR  ORD     135.0
# 197            1949        8.0      EV    4581  N13566    EWR  CMH      95.0
# 198            1951       -6.0      B6    1111  N294JB    JFK  RDU      78.0
#
#      distance  hour  minute         time_hour
# ...

# %%
flight_count=df4['flight'].value_counts()
flight_count
# Out:
# 1635    2
# 509     2
# 702     2
# 1053    1
# 31      1
#        ..
# 3459    1
# 565     1
# 3331    1
# 847     1
# 1111    1
# Name: flight, Length: 196, dtype: int64

# %%
dep=df4['dep_delay']
dep
# Out:
# 0     -4
# 1     -5
# 2     -4
# 3      1
# 4     -3
#       ..
# 194   -2
# 195   -2
# 196    9
# 197    0
# 198    0
# Name: dep_delay, Length: 199, dtype: int64

# %%
dep1=df4(['dep_delay']==0)
dep1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 dep1=df4(['dep_delay']==0)
#       2 dep1
#
# TypeError: 'DataFrame' object is not callable

# %%
df4['speed']=df4['distance']/df4['hour']
df4
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
df4.size
# Out:
# 3980

# %%
df4.shape
# Out:
# (199, 20)

# %%
df4.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'speed'],
#       dtype='object')

# %%
df4.drop_duplicates()
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
df4.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          3
# distance          0
# hour              0
# minute            0
# time_hour         0
# speed             0
# dtype: int64

# %%
time=df4['air_time']
time
# Out:
# 0       87.0
# 1      152.0
# 2      140.0
# 3      252.0
# 4      166.0
#        ...
# 194     36.0
# 195    152.0
# 196    135.0
# 197     95.0
# 198     78.0
# Name: air_time, Length: 199, dtype: float64

# %%
mean=time.mean()
mean
# Out:
# 168.98979591836735

# %%
time.fillna(mean,inplace=True)
time
# Out:
# 0       87.0
# 1      152.0
# 2      140.0
# 3      252.0
# 4      166.0
#        ...
# 194     36.0
# 195    152.0
# 196    135.0
# 197     95.0
# 198     78.0
# Name: air_time, Length: 199, dtype: float64

# %%
df4.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# speed             0
# dtype: int64

# %%
df5=pd.read_csv('Movie-Data.csv')
df5
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df5.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df5.size
# Out:
# 12000

# %%
df5.shape
# Out:
# (1000, 12)

# %%
df5.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df5.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
meta=df5['Metascore']
meta
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
#        ...
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
mean=meta.mean()
mean
# Out:
# 58.98504273504273

# %%
meta.fillna(mean,inplace=True)
meta
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
#        ...
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
df5.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore               0
# dtype: int64

# %%
max=df5['Revenue (Millions)'].max()
max
# Out:
# 936.63

# %%
df5[(df5['Revenue (Millions)']==max)]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
min=df5['Revenue (Millions)'].min()
min
# Out:
# 0.0

# %%
df5[(df5['Revenue (Millions)']==min)]
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
df5[(df5['Revenue (Millions)']==0)]
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
import matplotlib.pyplot as plt
plt.plot(df5['Runtime (Minutes)'])
